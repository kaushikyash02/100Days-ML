# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushikyash02/100Days-ML/blob/main/WorkingOnAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #1ec8524f35a789ee0a1a1bf591aab8a5

# %%
import requests

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=1ec8524f35a789ee0a1a1bf591aab8a5&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2   936075                   Michael
# 3   687163         Project Hail Mary
# 4      238             The Godfather
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    144.0851
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     85.8959
# 2  The story of Michael Jackson, one of the most ...   2026-04-22    375.7553
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    130.2689
# 4  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     38.1806
#
#    vote_average  vote_count
# 0         8.960        1795
# 1         8.723       30625
# 2         8.691        2995
# 3         8.690        5380
# 4         8.700       23076

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,100):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    f = pd.concat([df, temp_df], ignore_index=True)

# %%
f
# Out:
#          id                                     title  \
# 0    615777                                   Babylon
# 1    439584  I Can Quit Whenever I Want 3: Ad Honorem
# 2    249164                                 If I Stay
# 3     88273                            A Royal Affair
# 4     14447                A Matter of Loaf and Death
# 5     14283                            The Red Violin
# 6      3089                                 Red River
# 7      2252                          Eastern Promises
# 8       377                 A Nightmare on Elm Street
# 9     38528                               Horse Fever
# 10   377263                                    Frantz
# 11   271706                        Big Fish & Begonia
# 12    61791            Rise of the Planet of the Apes
# 13    33701                   French Fried Vacation 2
# 14     3110                                     Shane
# 15     2056                         The Station Agent
# ...

# %%
f.to_csv('movies.csv')
